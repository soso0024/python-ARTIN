# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pandas as pd
from sklearn import datasets

# %%
# Load the diabetes dataset
diabetes_dataset = datasets.load_diabetes()

# %%
# Print the shape of the entire data matrix
print('The full data matrix has shape', diabetes_dataset.data.shape)
# Out:
# The full data matrix has shape (442, 10)

# %%
# Select only one feature for simplicity
features = diabetes_dataset.data[:, np.newaxis, 2]
print('Selected feature:', features.shape)
print('Selected feature name:', diabetes_dataset.feature_names[2])
# Out:
# Selected feature: (442, 1)
# Selected feature name: bmi

# %%
# Initialize an array to store the performance metrics
# Columns: [0] training data size, [1] mean squared error, [2] variance score
performance_metrics = np.zeros((412, 3))

# %% [markdown]
# このコードの部分は、モデルの性能指標を保存するための配列を初期化しています。具体的には、`np.zeros((412, 3))` という命令は、すべての要素が0の、412行3列の配列を作成します。この配列は、後でループを通じて得られる性能指標を格納するために使用されます。
#
# 配列の各列は次のように割り当てられています：
#
# - 列[0]：トレーニングデータのサイズ（トレーニングに使用されるデータポイントの数）。
# - 列[1]：平均二乗誤差（Mean Squared Error, MSE）の値。これはモデルの予測がどの程度正確かを示す指標で、値が小さいほど良いとされます。
# - 列[2]：決定係数（Variance Score, \( R^2 \) スコア）。これはモデルがデータの変動をどれだけ説明できているかを示す指標で、値が1に近いほど良いとされます。
#
# ループ内で、各イテレーションにおいてモデルが訓練され、テストデータに対して評価された後、これらの性能指標が `performance_metrics` 配列に記録されます。これにより、トレーニングデータのサイズを変えたときにモデルの性能がどのように変化するかを後で分析することができます。

# %%
# Loop over different training data sizes
for i in range(441, 29, -1):
    print('============== TRAINING DATA SIZE: ', 442 - i, ' ===============')
    
    # Split the data
    train_features = features[:-i]
    test_features = features[-30:]
    train_targets = diabetes_dataset.target[:-i]
    test_targets = diabetes_dataset.target[-30:]
    
    # Explore the data
    print('Feature names:', diabetes_dataset.feature_names)
    print('Target shape:', diabetes_dataset.target.shape)
    print('Training features shape', train_features.shape)
    print('Test features shape', test_features.shape)
    print('Training targets shape', train_targets.shape)
    print('Test targets shape', test_targets.shape)
    
    # Initialize and fit the linear regression model
    from sklearn import linear_model
    linear_regression_model = linear_model.LinearRegression()
    linear_regression_model.fit(train_features, train_targets)
    print('Coefficients:', linear_regression_model.coef_)
    print('Intercept:', linear_regression_model.intercept_)
    
    # Make predictions on the test data
    predicted_targets = linear_regression_model.predict(test_features)
    
    # Evaluate the model performance
    from sklearn.metrics import mean_squared_error, r2_score
    mse = mean_squared_error(test_targets, predicted_targets)
    variance = r2_score(test_targets, predicted_targets)
    print("Mean squared error: %.2f" % mse)
    print('Variance score: %.2f' % variance)
    
    # Store the training sample size, MSE, and variance score
    performance_metrics[442 - i - 1] = [442 - i, mse, variance]
    
    print('')
# Out:
# ============== TRAINING DATA SIZE:  1  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (1, 1)
# Test features shape (30, 1)
# Training targets shape (1,)
# Test targets shape (30,)
# Coefficients: [0.]
# Intercept: 151.0
# Mean squared error: 5465.50
# Variance score: -0.06
#
# ============== TRAINING DATA SIZE:  2  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (2, 1)
# Test features shape (30, 1)
# Training targets shape (2,)
# Test targets shape (30,)
# Coefficients: [671.55447721]
# Intercept: 109.56763628528348
# Mean squared error: 3596.79
# Variance score: 0.30
#
# ============== TRAINING DATA SIZE:  3  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (3, 1)
# Test features shape (30, 1)
# Training targets shape (3,)
# Test targets shape (30,)
# Coefficients: [677.13085437]
# Intercept: 109.99299398959681
# Mean squared error: 3566.89
# Variance score: 0.31
#
# ============== TRAINING DATA SIZE:  4  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (4, 1)
# Test features shape (30, 1)
# Training targets shape (4,)
# Test targets shape (30,)
# Coefficients: [390.45717413]
# Intercept: 139.04493787302266
# Mean squared error: 3667.23
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  5  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (5, 1)
# Test features shape (30, 1)
# Training targets shape (5,)
# Test targets shape (30,)
# Coefficients: [351.66294632]
# Intercept: 141.12921812976313
# Mean squared error: 3812.96
# Variance score: 0.26
#
# ============== TRAINING DATA SIZE:  6  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (6, 1)
# Test features shape (30, 1)
# Training targets shape (6,)
# Test targets shape (30,)
# Coefficients: [443.65878486]
# Intercept: 136.680902339961
# Mean squared error: 3495.88
# Variance score: 0.32
#
# ============== TRAINING DATA SIZE:  7  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (7, 1)
# Test features shape (30, 1)
# Training targets shape (7,)
# Test targets shape (30,)
# Coefficients: [381.9930944]
# Intercept: 139.14350118477734
# Mean squared error: 3693.79
# Variance score: 0.28
#
# ============== TRAINING DATA SIZE:  8  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (8, 1)
# Test features shape (30, 1)
# Training targets shape (8,)
# Test targets shape (30,)
# Coefficients: [332.415215]
# Intercept: 129.20129296585404
# Mean squared error: 3843.01
# Variance score: 0.25
#
# ============== TRAINING DATA SIZE:  9  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (9, 1)
# Test features shape (30, 1)
# Training targets shape (9,)
# Test targets shape (30,)
# Coefficients: [187.27992178]
# Intercept: 124.44455261085564
# Mean squared error: 4424.46
# Variance score: 0.14
#
# ============== TRAINING DATA SIZE:  10  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (10, 1)
# Test features shape (30, 1)
# Training targets shape (10,)
# Test targets shape (30,)
# Coefficients: [535.74096196]
# Intercept: 141.65181606678206
# Mean squared error: 3312.05
# Variance score: 0.36
#
# ============== TRAINING DATA SIZE:  11  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (11, 1)
# Test features shape (30, 1)
# Training targets shape (11,)
# Test targets shape (30,)
# Coefficients: [522.89868802]
# Intercept: 141.96079681744854
# Mean squared error: 3347.28
# Variance score: 0.35
#
# ============== TRAINING DATA SIZE:  12  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (12, 1)
# Test features shape (30, 1)
# Training targets shape (12,)
# Test targets shape (30,)
# Coefficients: [455.4412826]
# Intercept: 134.8446874847255
# Mean squared error: 3457.39
# Variance score: 0.33
#
# ============== TRAINING DATA SIZE:  13  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (13, 1)
# Test features shape (30, 1)
# Training targets shape (13,)
# Test targets shape (30,)
# Coefficients: [406.53811105]
# Intercept: 138.96030186747674
# Mean squared error: 3618.74
# Variance score: 0.30
#
# ============== TRAINING DATA SIZE:  14  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (14, 1)
# Test features shape (30, 1)
# Training targets shape (14,)
# Test targets shape (30,)
# Coefficients: [413.12148945]
# Intercept: 142.34117935137124
# Mean squared error: 3644.90
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  15  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (15, 1)
# Test features shape (30, 1)
# Training targets shape (15,)
# Test targets shape (30,)
# Coefficients: [422.54001423]
# Intercept: 141.48957101679642
# Mean squared error: 3604.19
# Variance score: 0.30
#
# ============== TRAINING DATA SIZE:  16  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (16, 1)
# Test features shape (30, 1)
# Training targets shape (16,)
# Test targets shape (30,)
# Coefficients: [408.43039117]
# Intercept: 143.7024906848137
# Mean squared error: 3683.30
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  17  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (17, 1)
# Test features shape (30, 1)
# Training targets shape (17,)
# Test targets shape (30,)
# Coefficients: [416.39687723]
# Intercept: 144.03576672345312
# Mean squared error: 3666.70
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  18  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (18, 1)
# Test features shape (30, 1)
# Training targets shape (18,)
# Test targets shape (30,)
# Coefficients: [413.69271435]
# Intercept: 143.7431735617715
# Mean squared error: 3668.74
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  19  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (19, 1)
# Test features shape (30, 1)
# Training targets shape (19,)
# Test targets shape (30,)
# Coefficients: [422.67924431]
# Intercept: 141.54941871252245
# Mean squared error: 3604.70
# Variance score: 0.30
#
# ============== TRAINING DATA SIZE:  20  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (20, 1)
# Test features shape (30, 1)
# Training targets shape (20,)
# Test targets shape (30,)
# Coefficients: [407.75511977]
# Intercept: 143.18115533286326
# Mean squared error: 3675.38
# Variance score: 0.29
#
# ============== TRAINING DATA SIZE:  21  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (21, 1)
# Test features shape (30, 1)
# Training targets shape (21,)
# Test targets shape (30,)
# Coefficients: [486.43482988]
# Intercept: 141.28232925961427
# Mean squared error: 3427.72
# Variance score: 0.33
#
# ============== TRAINING DATA SIZE:  22  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (22, 1)
# Test features shape (30, 1)
# Training targets shape (22,)
# Test targets shape (30,)
# Coefficients: [521.90018203]
# Intercept: 137.86674685445288
# Mean squared error: 3302.25
# Variance score: 0.36
#
# ============== TRAINING DATA SIZE:  23  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (23, 1)
# Test features shape (30, 1)
# Training targets shape (23,)
# Test targets shape (30,)
# Coefficients: [514.09783396]
# Intercept: 134.8597514849778
# Mean squared error: 3307.51
# Variance score: 0.36
#
# ============== TRAINING DATA SIZE:  24  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (24, 1)
# Test features shape (30, 1)
# Training targets shape (24,)
# Test targets shape (30,)
# Coefficients: [652.45133666]
# Intercept: 138.8412939851944
# Mean squared error: 3036.13
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  25  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (25, 1)
# Test features shape (30, 1)
# Training targets shape (25,)
# Test targets shape (30,)
# Coefficients: [674.30951858]
# Intercept: 139.78603754229815
# Mean squared error: 3007.14
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  26  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (26, 1)
# Test features shape (30, 1)
# Training targets shape (26,)
# Test targets shape (30,)
# Coefficients: [658.12028626]
# Intercept: 142.44734894944375
# Mean squared error: 3071.48
# Variance score: 0.40
#
# ============== TRAINING DATA SIZE:  27  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (27, 1)
# Test features shape (30, 1)
# Training targets shape (27,)
# Test targets shape (30,)
# Coefficients: [585.47130426]
# Intercept: 143.66252540446084
# Mean squared error: 3235.00
# Variance score: 0.37
#
# ============== TRAINING DATA SIZE:  28  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (28, 1)
# Test features shape (30, 1)
# Training targets shape (28,)
# Test targets shape (30,)
# Coefficients: [462.9137674]
# Intercept: 139.8213440156877
# Mean squared error: 3470.33
# Variance score: 0.33
#
# ============== TRAINING DATA SIZE:  29  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (29, 1)
# Test features shape (30, 1)
# Training targets shape (29,)
# Test targets shape (30,)
# Coefficients: [462.56118189]
# Intercept: 139.85543640749
# Mean squared error: 3471.66
# Variance score: 0.33
#
# ============== TRAINING DATA SIZE:  30  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (30, 1)
# Test features shape (30, 1)
# Training targets shape (30,)
# Test targets shape (30,)
# Coefficients: [458.15762507]
# Intercept: 144.70176785409558
# Mean squared error: 3563.53
# Variance score: 0.31
#
# ============== TRAINING DATA SIZE:  31  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (31, 1)
# Test features shape (30, 1)
# Training targets shape (31,)
# Test targets shape (30,)
# Coefficients: [424.61728133]
# Intercept: 143.43277241615166
# Mean squared error: 3631.27
# Variance score: 0.30
#
# ============== TRAINING DATA SIZE:  32  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (32, 1)
# Test features shape (30, 1)
# Training targets shape (32,)
# Test targets shape (30,)
# Coefficients: [486.85254678]
# Intercept: 141.98025103705345
# Mean squared error: 3437.21
# Variance score: 0.33
#
# ============== TRAINING DATA SIZE:  33  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (33, 1)
# Test features shape (30, 1)
# Training targets shape (33,)
# Test targets shape (30,)
# Coefficients: [731.14359571]
# Intercept: 146.44212585634452
# Mean squared error: 3032.80
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  34  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (34, 1)
# Test features shape (30, 1)
# Training targets shape (34,)
# Test targets shape (30,)
# Coefficients: [745.78224345]
# Intercept: 145.81550527643677
# Mean squared error: 2997.16
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  35  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (35, 1)
# Test features shape (30, 1)
# Training targets shape (35,)
# Test targets shape (30,)
# Coefficients: [771.39401275]
# Intercept: 144.96676487462236
# Mean squared error: 2944.30
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  36  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (36, 1)
# Test features shape (30, 1)
# Training targets shape (36,)
# Test targets shape (30,)
# Coefficients: [777.72351312]
# Intercept: 144.46948556061233
# Mean squared error: 2926.14
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  37  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (37, 1)
# Test features shape (30, 1)
# Training targets shape (37,)
# Test targets shape (30,)
# Coefficients: [813.18104807]
# Intercept: 147.3987355622042
# Mean squared error: 2951.17
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  38  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (38, 1)
# Test features shape (30, 1)
# Training targets shape (38,)
# Test targets shape (30,)
# Coefficients: [835.80007384]
# Intercept: 150.6351561805965
# Mean squared error: 3020.71
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  39  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (39, 1)
# Test features shape (30, 1)
# Training targets shape (39,)
# Test targets shape (30,)
# Coefficients: [871.9688656]
# Intercept: 151.77570028974196
# Mean squared error: 3025.02
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  40  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (40, 1)
# Test features shape (30, 1)
# Training targets shape (40,)
# Test targets shape (30,)
# Coefficients: [858.10742226]
# Intercept: 149.89839758243457
# Mean squared error: 2976.38
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  41  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (41, 1)
# Test features shape (30, 1)
# Training targets shape (41,)
# Test targets shape (30,)
# Coefficients: [861.44180981]
# Intercept: 148.86215847930282
# Mean squared error: 2942.88
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  42  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (42, 1)
# Test features shape (30, 1)
# Training targets shape (42,)
# Test targets shape (30,)
# Coefficients: [887.13612938]
# Intercept: 148.09965085613234
# Mean squared error: 2900.65
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  43  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (43, 1)
# Test features shape (30, 1)
# Training targets shape (43,)
# Test targets shape (30,)
# Coefficients: [893.27890983]
# Intercept: 146.312397698721
# Mean squared error: 2851.35
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  44  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (44, 1)
# Test features shape (30, 1)
# Training targets shape (44,)
# Test targets shape (30,)
# Coefficients: [900.55182515]
# Intercept: 145.5826882415552
# Mean squared error: 2829.77
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  45  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (45, 1)
# Test features shape (30, 1)
# Training targets shape (45,)
# Test targets shape (30,)
# Coefficients: [939.30532915]
# Intercept: 146.82910958733115
# Mean squared error: 2834.74
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  46  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (46, 1)
# Test features shape (30, 1)
# Training targets shape (46,)
# Test targets shape (30,)
# Coefficients: [959.75634183]
# Intercept: 145.57253011322396
# Mean squared error: 2796.37
# Variance score: 0.46
#
# ============== TRAINING DATA SIZE:  47  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (47, 1)
# Test features shape (30, 1)
# Training targets shape (47,)
# Test targets shape (30,)
# Coefficients: [954.90122752]
# Intercept: 146.73891302200212
# Mean squared error: 2824.98
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  48  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (48, 1)
# Test features shape (30, 1)
# Training targets shape (48,)
# Test targets shape (30,)
# Coefficients: [910.71737276]
# Intercept: 147.88629549067275
# Mean squared error: 2878.24
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  49  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (49, 1)
# Test features shape (30, 1)
# Training targets shape (49,)
# Test targets shape (30,)
# Coefficients: [923.14241388]
# Intercept: 147.24277353473076
# Mean squared error: 2853.94
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  50  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (50, 1)
# Test features shape (30, 1)
# Training targets shape (50,)
# Test targets shape (30,)
# Coefficients: [919.66427967]
# Intercept: 146.856871054288
# Mean squared error: 2846.55
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  51  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (51, 1)
# Test features shape (30, 1)
# Training targets shape (51,)
# Test targets shape (30,)
# Coefficients: [919.3453565]
# Intercept: 147.1462637283638
# Mean squared error: 2853.84
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  52  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (52, 1)
# Test features shape (30, 1)
# Training targets shape (52,)
# Test targets shape (30,)
# Coefficients: [932.23311036]
# Intercept: 148.41322024311293
# Mean squared error: 2879.28
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  53  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (53, 1)
# Test features shape (30, 1)
# Training targets shape (53,)
# Test targets shape (30,)
# Coefficients: [935.90238468]
# Intercept: 146.90968408242804
# Mean squared error: 2838.49
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  54  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (54, 1)
# Test features shape (30, 1)
# Training targets shape (54,)
# Test targets shape (30,)
# Coefficients: [938.88163215]
# Intercept: 146.4055423950783
# Mean squared error: 2824.93
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  55  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (55, 1)
# Test features shape (30, 1)
# Training targets shape (55,)
# Test targets shape (30,)
# Coefficients: [942.31132978]
# Intercept: 146.64025467424625
# Mean squared error: 2828.67
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  56  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (56, 1)
# Test features shape (30, 1)
# Training targets shape (56,)
# Test targets shape (30,)
# Coefficients: [930.7054666]
# Intercept: 147.0766403495512
# Mean squared error: 2845.43
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  57  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (57, 1)
# Test features shape (30, 1)
# Training targets shape (57,)
# Test targets shape (30,)
# Coefficients: [874.26047907]
# Intercept: 144.48671854980532
# Mean squared error: 2826.91
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  58  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (58, 1)
# Test features shape (30, 1)
# Training targets shape (58,)
# Test targets shape (30,)
# Coefficients: [901.381805]
# Intercept: 143.73524710465935
# Mean squared error: 2792.45
# Variance score: 0.46
#
# ============== TRAINING DATA SIZE:  59  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (59, 1)
# Test features shape (30, 1)
# Training targets shape (59,)
# Test targets shape (30,)
# Coefficients: [858.75510868]
# Intercept: 144.89052904710374
# Mean squared error: 2848.15
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  60  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (60, 1)
# Test features shape (30, 1)
# Training targets shape (60,)
# Test targets shape (30,)
# Coefficients: [851.03405817]
# Intercept: 145.6234390579356
# Mean squared error: 2870.67
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  61  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (61, 1)
# Test features shape (30, 1)
# Training targets shape (61,)
# Test targets shape (30,)
# Coefficients: [849.16428453]
# Intercept: 144.280148480967
# Mean squared error: 2844.68
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  62  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (62, 1)
# Test features shape (30, 1)
# Training targets shape (62,)
# Test targets shape (30,)
# Coefficients: [848.76348549]
# Intercept: 144.21039590155453
# Mean squared error: 2843.72
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  63  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (63, 1)
# Test features shape (30, 1)
# Training targets shape (63,)
# Test targets shape (30,)
# Coefficients: [849.32566706]
# Intercept: 142.84854051252609
# Mean squared error: 2818.97
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  64  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (64, 1)
# Test features shape (30, 1)
# Training targets shape (64,)
# Test targets shape (30,)
# Coefficients: [844.87658612]
# Intercept: 143.08247898294846
# Mean squared error: 2827.01
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  65  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (65, 1)
# Test features shape (30, 1)
# Training targets shape (65,)
# Test targets shape (30,)
# Coefficients: [852.80555549]
# Intercept: 142.36423881349174
# Mean squared error: 2808.08
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  66  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (66, 1)
# Test features shape (30, 1)
# Training targets shape (66,)
# Test targets shape (30,)
# Coefficients: [846.76728716]
# Intercept: 142.9481875612886
# Mean squared error: 2822.98
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  67  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (67, 1)
# Test features shape (30, 1)
# Training targets shape (67,)
# Test targets shape (30,)
# Coefficients: [844.78958712]
# Intercept: 143.26644625578442
# Mean squared error: 2830.23
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  68  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (68, 1)
# Test features shape (30, 1)
# Training targets shape (68,)
# Test targets shape (30,)
# Coefficients: [846.81116832]
# Intercept: 142.78609093039626
# Mean squared error: 2820.27
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  69  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (69, 1)
# Test features shape (30, 1)
# Training targets shape (69,)
# Test targets shape (30,)
# Coefficients: [838.91975139]
# Intercept: 143.33847912100063
# Mean squared error: 2837.09
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  70  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (70, 1)
# Test features shape (30, 1)
# Training targets shape (70,)
# Test targets shape (30,)
# Coefficients: [815.8412126]
# Intercept: 144.18551721893135
# Mean squared error: 2876.22
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  71  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (71, 1)
# Test features shape (30, 1)
# Training targets shape (71,)
# Test targets shape (30,)
# Coefficients: [835.14143085]
# Intercept: 143.8170411613577
# Mean squared error: 2849.37
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  72  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (72, 1)
# Test features shape (30, 1)
# Training targets shape (72,)
# Test targets shape (30,)
# Coefficients: [868.7504055]
# Intercept: 145.47964726576336
# Mean squared error: 2851.94
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  73  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (73, 1)
# Test features shape (30, 1)
# Training targets shape (73,)
# Test targets shape (30,)
# Coefficients: [871.08106927]
# Intercept: 146.3227928161884
# Mean squared error: 2868.94
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  74  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (74, 1)
# Test features shape (30, 1)
# Training targets shape (74,)
# Test targets shape (30,)
# Coefficients: [872.672427]
# Intercept: 146.09781795486927
# Mean squared error: 2862.43
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  75  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (75, 1)
# Test features shape (30, 1)
# Training targets shape (75,)
# Test targets shape (30,)
# Coefficients: [866.94378928]
# Intercept: 145.2041982202043
# Mean squared error: 2847.58
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  76  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (76, 1)
# Test features shape (30, 1)
# Training targets shape (76,)
# Test targets shape (30,)
# Coefficients: [880.26010608]
# Intercept: 144.32193001472322
# Mean squared error: 2818.92
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  77  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (77, 1)
# Test features shape (30, 1)
# Training targets shape (77,)
# Test targets shape (30,)
# Coefficients: [880.48828017]
# Intercept: 144.33405117177168
# Mean squared error: 2818.97
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  78  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (78, 1)
# Test features shape (30, 1)
# Training targets shape (78,)
# Test targets shape (30,)
# Coefficients: [861.64149317]
# Intercept: 145.28808911329693
# Mean squared error: 2853.92
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  79  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (79, 1)
# Test features shape (30, 1)
# Training targets shape (79,)
# Test targets shape (30,)
# Coefficients: [803.29205599]
# Intercept: 146.707305844813
# Mean squared error: 2944.99
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  80  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (80, 1)
# Test features shape (30, 1)
# Training targets shape (80,)
# Test targets shape (30,)
# Coefficients: [804.05315233]
# Intercept: 146.6697461256603
# Mean squared error: 2943.21
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  81  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (81, 1)
# Test features shape (30, 1)
# Training targets shape (81,)
# Test targets shape (30,)
# Coefficients: [801.81378152]
# Intercept: 146.48236785355786
# Mean squared error: 2941.27
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  82  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (82, 1)
# Test features shape (30, 1)
# Training targets shape (82,)
# Test targets shape (30,)
# Coefficients: [809.20411024]
# Intercept: 145.60978101991523
# Mean squared error: 2912.88
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  83  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (83, 1)
# Test features shape (30, 1)
# Training targets shape (83,)
# Test targets shape (30,)
# Coefficients: [821.6107183]
# Intercept: 144.95262999348034
# Mean squared error: 2885.39
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  84  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (84, 1)
# Test features shape (30, 1)
# Training targets shape (84,)
# Test targets shape (30,)
# Coefficients: [830.18543939]
# Intercept: 145.7149129506044
# Mean squared error: 2892.89
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  85  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (85, 1)
# Test features shape (30, 1)
# Training targets shape (85,)
# Test targets shape (30,)
# Coefficients: [840.73284595]
# Intercept: 145.26092712910514
# Mean squared error: 2872.56
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  86  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (86, 1)
# Test features shape (30, 1)
# Training targets shape (86,)
# Test targets shape (30,)
# Coefficients: [803.52804722]
# Intercept: 144.1654850681597
# Mean squared error: 2889.44
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  87  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (87, 1)
# Test features shape (30, 1)
# Training targets shape (87,)
# Test targets shape (30,)
# Coefficients: [816.53884962]
# Intercept: 143.96652633749773
# Mean squared error: 2871.31
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  88  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (88, 1)
# Test features shape (30, 1)
# Training targets shape (88,)
# Test targets shape (30,)
# Coefficients: [816.40743113]
# Intercept: 143.90953187756452
# Mean squared error: 2870.39
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  89  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (89, 1)
# Test features shape (30, 1)
# Training targets shape (89,)
# Test targets shape (30,)
# Coefficients: [830.77898336]
# Intercept: 143.28737172599799
# Mean squared error: 2844.24
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  90  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (90, 1)
# Test features shape (30, 1)
# Training targets shape (90,)
# Test targets shape (30,)
# Coefficients: [828.78512818]
# Intercept: 143.35233585469007
# Mean squared error: 2847.39
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  91  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (91, 1)
# Test features shape (30, 1)
# Training targets shape (91,)
# Test targets shape (30,)
# Coefficients: [831.19437568]
# Intercept: 143.11365108417692
# Mean squared error: 2840.84
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  92  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (92, 1)
# Test features shape (30, 1)
# Training targets shape (92,)
# Test targets shape (30,)
# Coefficients: [821.93767414]
# Intercept: 142.77550557573366
# Mean squared error: 2844.67
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  93  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (93, 1)
# Test features shape (30, 1)
# Training targets shape (93,)
# Test targets shape (30,)
# Coefficients: [812.30306866]
# Intercept: 141.61824912306693
# Mean squared error: 2837.31
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  94  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (94, 1)
# Test features shape (30, 1)
# Training targets shape (94,)
# Test targets shape (30,)
# Coefficients: [809.95878683]
# Intercept: 141.66439095269763
# Mean squared error: 2840.52
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  95  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (95, 1)
# Test features shape (30, 1)
# Training targets shape (95,)
# Test targets shape (30,)
# Coefficients: [811.4887993]
# Intercept: 141.28186753314696
# Mean squared error: 2833.57
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  96  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (96, 1)
# Test features shape (30, 1)
# Training targets shape (96,)
# Test targets shape (30,)
# Coefficients: [791.1866885]
# Intercept: 141.75843554787068
# Mean squared error: 2863.24
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  97  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (97, 1)
# Test features shape (30, 1)
# Training targets shape (97,)
# Test targets shape (30,)
# Coefficients: [791.23521433]
# Intercept: 141.76268752298944
# Mean squared error: 2863.24
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  98  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (98, 1)
# Test features shape (30, 1)
# Training targets shape (98,)
# Test targets shape (30,)
# Coefficients: [831.13480526]
# Intercept: 142.84815476500313
# Mean squared error: 2836.45
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  99  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (99, 1)
# Test features shape (30, 1)
# Training targets shape (99,)
# Test targets shape (30,)
# Coefficients: [829.76898797]
# Intercept: 142.36393850238852
# Mean squared error: 2830.08
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  100  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (100, 1)
# Test features shape (30, 1)
# Training targets shape (100,)
# Test targets shape (30,)
# Coefficients: [831.65700359]
# Intercept: 142.3246324594354
# Mean squared error: 2827.57
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  101  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (101, 1)
# Test features shape (30, 1)
# Training targets shape (101,)
# Test targets shape (30,)
# Coefficients: [826.93091622]
# Intercept: 141.9901619513762
# Mean squared error: 2827.29
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  102  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (102, 1)
# Test features shape (30, 1)
# Training targets shape (102,)
# Test targets shape (30,)
# Coefficients: [827.48905879]
# Intercept: 141.9688995644647
# Mean squared error: 2826.41
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  103  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (103, 1)
# Test features shape (30, 1)
# Training targets shape (103,)
# Test targets shape (30,)
# Coefficients: [858.00824193]
# Intercept: 143.60740359148133
# Mean squared error: 2824.17
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  104  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (104, 1)
# Test features shape (30, 1)
# Training targets shape (104,)
# Test targets shape (30,)
# Coefficients: [863.54726317]
# Intercept: 143.84425169637183
# Mean squared error: 2823.65
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  105  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (105, 1)
# Test features shape (30, 1)
# Training targets shape (105,)
# Test targets shape (30,)
# Coefficients: [820.57338649]
# Intercept: 142.45750889258076
# Mean squared error: 2841.00
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  106  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (106, 1)
# Test features shape (30, 1)
# Training targets shape (106,)
# Test targets shape (30,)
# Coefficients: [828.53722624]
# Intercept: 141.93541320490175
# Mean squared error: 2824.85
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  107  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (107, 1)
# Test features shape (30, 1)
# Training targets shape (107,)
# Test targets shape (30,)
# Coefficients: [808.76042637]
# Intercept: 142.2567385813709
# Mean squared error: 2850.59
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  108  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (108, 1)
# Test features shape (30, 1)
# Training targets shape (108,)
# Test targets shape (30,)
# Coefficients: [796.69350354]
# Intercept: 141.78731100840724
# Mean squared error: 2857.22
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  109  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (109, 1)
# Test features shape (30, 1)
# Training targets shape (109,)
# Test targets shape (30,)
# Coefficients: [811.95670814]
# Intercept: 142.41658960967396
# Mean squared error: 2849.57
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  110  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (110, 1)
# Test features shape (30, 1)
# Training targets shape (110,)
# Test targets shape (30,)
# Coefficients: [812.1322482]
# Intercept: 141.92948003686308
# Mean squared error: 2841.98
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  111  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (111, 1)
# Test features shape (30, 1)
# Training targets shape (111,)
# Test targets shape (30,)
# Coefficients: [813.5546238]
# Intercept: 141.8352710509788
# Mean squared error: 2839.06
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  112  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (112, 1)
# Test features shape (30, 1)
# Training targets shape (112,)
# Test targets shape (30,)
# Coefficients: [807.50440958]
# Intercept: 141.00860890768135
# Mean squared error: 2834.35
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  113  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (113, 1)
# Test features shape (30, 1)
# Training targets shape (113,)
# Test targets shape (30,)
# Coefficients: [820.89408087]
# Intercept: 141.9051941639784
# Mean squared error: 2832.28
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  114  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (114, 1)
# Test features shape (30, 1)
# Training targets shape (114,)
# Test targets shape (30,)
# Coefficients: [837.66659297]
# Intercept: 143.30441459391648
# Mean squared error: 2837.72
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  115  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (115, 1)
# Test features shape (30, 1)
# Training targets shape (115,)
# Test targets shape (30,)
# Coefficients: [850.31888922]
# Intercept: 143.5927787018958
# Mean squared error: 2830.83
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  116  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (116, 1)
# Test features shape (30, 1)
# Training targets shape (116,)
# Test targets shape (30,)
# Coefficients: [853.82832238]
# Intercept: 144.34495943837948
# Mean squared error: 2841.67
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  117  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (117, 1)
# Test features shape (30, 1)
# Training targets shape (117,)
# Test targets shape (30,)
# Coefficients: [878.61790302]
# Intercept: 145.20279987944573
# Mean squared error: 2837.97
# Variance score: 0.45
#
# ============== TRAINING DATA SIZE:  118  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (118, 1)
# Test features shape (30, 1)
# Training targets shape (118,)
# Test targets shape (30,)
# Coefficients: [868.15251643]
# Intercept: 146.44006974061045
# Mean squared error: 2874.14
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  119  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (119, 1)
# Test features shape (30, 1)
# Training targets shape (119,)
# Test targets shape (30,)
# Coefficients: [867.44764604]
# Intercept: 146.78553104740004
# Mean squared error: 2882.99
# Variance score: 0.44
#
# ============== TRAINING DATA SIZE:  120  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (120, 1)
# Test features shape (30, 1)
# Training targets shape (120,)
# Test targets shape (30,)
# Coefficients: [849.91831018]
# Intercept: 147.44270496328855
# Mean squared error: 2914.99
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  121  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (121, 1)
# Test features shape (30, 1)
# Training targets shape (121,)
# Test targets shape (30,)
# Coefficients: [852.58120751]
# Intercept: 147.864011178134
# Mean squared error: 2923.49
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  122  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (122, 1)
# Test features shape (30, 1)
# Training targets shape (122,)
# Test targets shape (30,)
# Coefficients: [853.74287648]
# Intercept: 147.9557876788024
# Mean squared error: 2924.86
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  123  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (123, 1)
# Test features shape (30, 1)
# Training targets shape (123,)
# Test targets shape (30,)
# Coefficients: [839.15797926]
# Intercept: 147.56239234180754
# Mean squared error: 2928.37
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  124  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (124, 1)
# Test features shape (30, 1)
# Training targets shape (124,)
# Test targets shape (30,)
# Coefficients: [822.35482163]
# Intercept: 146.7153052217766
# Mean squared error: 2924.24
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  125  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (125, 1)
# Test features shape (30, 1)
# Training targets shape (125,)
# Test targets shape (30,)
# Coefficients: [816.37645267]
# Intercept: 146.3179642256657
# Mean squared error: 2921.15
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  126  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (126, 1)
# Test features shape (30, 1)
# Training targets shape (126,)
# Test targets shape (30,)
# Coefficients: [816.12163803]
# Intercept: 146.48721388886747
# Mean squared error: 2925.42
# Variance score: 0.43
#
# ============== TRAINING DATA SIZE:  127  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (127, 1)
# Test features shape (30, 1)
# Training targets shape (127,)
# Test targets shape (30,)
# ...
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (371, 1)
# Test features shape (30, 1)
# Training targets shape (371,)
# Test targets shape (30,)
# Coefficients: [951.1295633]
# Intercept: 152.78743037337892
# Mean squared error: 3007.79
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  372  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (372, 1)
# Test features shape (30, 1)
# Training targets shape (372,)
# Test targets shape (30,)
# Coefficients: [950.5237357]
# Intercept: 152.93047401925045
# Mean squared error: 3013.25
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  373  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (373, 1)
# Test features shape (30, 1)
# Training targets shape (373,)
# Test targets shape (30,)
# Coefficients: [952.19559442]
# Intercept: 152.77052724317676
# Mean squared error: 3006.66
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  374  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (374, 1)
# Test features shape (30, 1)
# Training targets shape (374,)
# Test targets shape (30,)
# Coefficients: [951.87857835]
# Intercept: 152.83802572511493
# Mean squared error: 3009.25
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  375  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (375, 1)
# Test features shape (30, 1)
# Training targets shape (375,)
# Test targets shape (30,)
# Coefficients: [951.07512547]
# Intercept: 152.89060631640874
# Mean squared error: 3011.54
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  376  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (376, 1)
# Test features shape (30, 1)
# Training targets shape (376,)
# Test targets shape (30,)
# Coefficients: [950.84551933]
# Intercept: 153.06860716892396
# Mean squared error: 3018.12
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  377  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (377, 1)
# Test features shape (30, 1)
# Training targets shape (377,)
# Test targets shape (30,)
# Coefficients: [943.02798148]
# Intercept: 152.8123043574787
# Mean squared error: 3012.78
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  378  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (378, 1)
# Test features shape (30, 1)
# Training targets shape (378,)
# Test targets shape (30,)
# Coefficients: [943.87765494]
# Intercept: 153.00478530992189
# Mean squared error: 3019.32
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  379  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (379, 1)
# Test features shape (30, 1)
# Training targets shape (379,)
# Test targets shape (30,)
# Coefficients: [944.12197388]
# Intercept: 153.24146948020953
# Mean squared error: 3027.87
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  380  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (380, 1)
# Test features shape (30, 1)
# Training targets shape (380,)
# Test targets shape (30,)
# Coefficients: [947.62780457]
# Intercept: 153.03916067100937
# Mean squared error: 3018.65
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  381  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (381, 1)
# Test features shape (30, 1)
# Training targets shape (381,)
# Test targets shape (30,)
# Coefficients: [943.75494914]
# Intercept: 152.70931036228575
# Mean squared error: 3008.70
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  382  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (382, 1)
# Test features shape (30, 1)
# Training targets shape (382,)
# Test targets shape (30,)
# Coefficients: [940.05574083]
# Intercept: 152.80161883617293
# Mean squared error: 3013.98
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  383  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (383, 1)
# Test features shape (30, 1)
# Training targets shape (383,)
# Test targets shape (30,)
# Coefficients: [934.55824191]
# Intercept: 152.59857898460757
# Mean squared error: 3009.72
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  384  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (384, 1)
# Test features shape (30, 1)
# Training targets shape (384,)
# Test targets shape (30,)
# Coefficients: [935.82021659]
# Intercept: 152.5006243680285
# Mean squared error: 3005.53
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  385  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (385, 1)
# Test features shape (30, 1)
# Training targets shape (385,)
# Test targets shape (30,)
# Coefficients: [937.74348285]
# Intercept: 152.35673443998277
# Mean squared error: 2999.39
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  386  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (386, 1)
# Test features shape (30, 1)
# Training targets shape (386,)
# Test targets shape (30,)
# Coefficients: [935.87892104]
# Intercept: 152.575526199253
# Mean squared error: 3008.16
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  387  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (387, 1)
# Test features shape (30, 1)
# Training targets shape (387,)
# Test targets shape (30,)
# Coefficients: [937.87194217]
# Intercept: 152.46632547847352
# Mean squared error: 3003.18
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  388  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (388, 1)
# Test features shape (30, 1)
# Training targets shape (388,)
# Test targets shape (30,)
# Coefficients: [938.49031627]
# Intercept: 152.55446577783215
# Mean squared error: 3005.97
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  389  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (389, 1)
# Test features shape (30, 1)
# Training targets shape (389,)
# Test targets shape (30,)
# Coefficients: [939.03889985]
# Intercept: 152.5044231894082
# Mean squared error: 3003.90
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  390  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (390, 1)
# Test features shape (30, 1)
# Training targets shape (390,)
# Test targets shape (30,)
# Coefficients: [938.84190961]
# Intercept: 152.24087021511863
# Mean squared error: 2994.73
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  391  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (391, 1)
# Test features shape (30, 1)
# Training targets shape (391,)
# Test targets shape (30,)
# Coefficients: [943.62363039]
# Intercept: 152.39434131345928
# Mean squared error: 2997.57
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  392  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (392, 1)
# Test features shape (30, 1)
# Training targets shape (392,)
# Test targets shape (30,)
# Coefficients: [945.4992184]
# Intercept: 152.3348981915315
# Mean squared error: 2994.52
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  393  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (393, 1)
# Test features shape (30, 1)
# Training targets shape (393,)
# Test targets shape (30,)
# Coefficients: [945.70385676]
# Intercept: 152.31958945445854
# Mean squared error: 2993.87
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  394  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (394, 1)
# Test features shape (30, 1)
# Training targets shape (394,)
# Test targets shape (30,)
# Coefficients: [947.77442211]
# Intercept: 152.21978028244766
# Mean squared error: 2989.34
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  395  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (395, 1)
# Test features shape (30, 1)
# Training targets shape (395,)
# Test targets shape (30,)
# Coefficients: [950.01912718]
# Intercept: 152.4819878540695
# Mean squared error: 2997.43
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  396  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (396, 1)
# Test features shape (30, 1)
# Training targets shape (396,)
# Test targets shape (30,)
# Coefficients: [950.2324679]
# Intercept: 152.74533228369302
# Mean squared error: 3006.71
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  397  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (397, 1)
# Test features shape (30, 1)
# Training targets shape (397,)
# Test targets shape (30,)
# Coefficients: [953.02484976]
# Intercept: 152.54456222746785
# Mean squared error: 2998.19
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  398  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (398, 1)
# Test features shape (30, 1)
# Training targets shape (398,)
# Test targets shape (30,)
# Coefficients: [952.82712752]
# Intercept: 152.6683641590642
# Mean squared error: 3002.70
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  399  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (399, 1)
# Test features shape (30, 1)
# Training targets shape (399,)
# Test targets shape (30,)
# Coefficients: [954.17822258]
# Intercept: 152.85626894017216
# Mean squared error: 3008.80
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  400  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (400, 1)
# Test features shape (30, 1)
# Training targets shape (400,)
# Test targets shape (30,)
# Coefficients: [955.70303385]
# Intercept: 153.0001839567591
# Mean squared error: 3013.30
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  401  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (401, 1)
# Test features shape (30, 1)
# Training targets shape (401,)
# Test targets shape (30,)
# Coefficients: [954.58075471]
# Intercept: 152.94617227674146
# Mean squared error: 3011.87
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  402  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (402, 1)
# Test features shape (30, 1)
# Training targets shape (402,)
# Test targets shape (30,)
# Coefficients: [955.44001079]
# Intercept: 152.90430035543224
# Mean squared error: 3009.95
# Variance score: 0.42
#
# ============== TRAINING DATA SIZE:  403  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (403, 1)
# Test features shape (30, 1)
# Training targets shape (403,)
# Test targets shape (30,)
# Coefficients: [953.70956055]
# Intercept: 153.01945903743717
# Mean squared error: 3014.95
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  404  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (404, 1)
# Test features shape (30, 1)
# Training targets shape (404,)
# Test targets shape (30,)
# Coefficients: [956.90623381]
# Intercept: 153.09266322814472
# Mean squared error: 3016.12
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  405  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (405, 1)
# Test features shape (30, 1)
# Training targets shape (405,)
# Test targets shape (30,)
# Coefficients: [962.25286611]
# Intercept: 153.310921453624
# Mean squared error: 3021.74
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  406  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (406, 1)
# Test features shape (30, 1)
# Training targets shape (406,)
# Test targets shape (30,)
# Coefficients: [963.49726265]
# Intercept: 153.33339250715
# Mean squared error: 3022.03
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  407  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (407, 1)
# Test features shape (30, 1)
# Training targets shape (407,)
# Test targets shape (30,)
# Coefficients: [963.82249207]
# Intercept: 153.32431415297825
# Mean squared error: 3021.55
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  408  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (408, 1)
# Test features shape (30, 1)
# Training targets shape (408,)
# Test targets shape (30,)
# Coefficients: [953.49975868]
# Intercept: 153.07405767335678
# Mean squared error: 3017.04
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  409  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (409, 1)
# Test features shape (30, 1)
# Training targets shape (409,)
# Test targets shape (30,)
# Coefficients: [948.92975427]
# Intercept: 153.27969795506127
# Mean squared error: 3026.83
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  410  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (410, 1)
# Test features shape (30, 1)
# Training targets shape (410,)
# Test targets shape (30,)
# Coefficients: [948.4439778]
# Intercept: 153.3741641565664
# Mean squared error: 3030.58
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  411  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (411, 1)
# Test features shape (30, 1)
# Training targets shape (411,)
# Test targets shape (30,)
# Coefficients: [945.99524462]
# Intercept: 153.57350478615788
# Mean squared error: 3039.27
# Variance score: 0.41
#
# ============== TRAINING DATA SIZE:  412  ===============
# Feature names: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Target shape: (442,)
# Training features shape (412, 1)
# Test features shape (30, 1)
# Training targets shape (412,)
# Test targets shape (30,)
# Coefficients: [941.43097333]
# Intercept: 153.39713623331644
# Mean squared error: 3035.06
# Variance score: 0.41

# %% [markdown]
# この `for` ループは、糖尿病データセットにおける異なるサイズの訓練データを使って線形回帰モデルの性能を評価するために使われています。
#
# ```python
# for i in range(441, 29, -1):
# ```
#
# この行は `range` 関数を使用しています。`range` 関数は3つの引数を取ります: 開始値、終了値、およびステップサイズです。この場合:
#
# - `441` はループの開始値で、`i` の初期値です。
# - `29` はループが停止する値で、`i` がこの値に到達したときにループは停止します（この値は含まれません）。
# - `-1` は各イテレーションで `i` から引かれる値、つまりステップサイズです。
#
# このループは、`i` が `441` から開始して、各イテレーションで `1` ずつ減少し、`30` になるまで続きます（`29` は含まれないため）。それぞれのイテレーションで、トレーニングセットから異なる数のデータポイントを使用してモデルを訓練し、固定されたサイズのテストセット（最後の30個のデータポイント）でモデルの性能を評価します。
#
# つまり、このコードはトレーニングデータセットのサイズを徐々に減らしながらモデルを訓練し、それぞれのサイズに対するモデルの性能（平均二乗誤差と決定係数）を計済み、記録しています。これにより、トレーニングデータの量がモデルの性能にどのように影響するかを観察することができます。

# %%
# Plot Mean Squared Error vs. Training Samples
plt.figure(figsize=(10, 5))
plt.plot(performance_metrics[:, 0], performance_metrics[:, 1], color='darkorange', marker='o', linestyle='-')
plt.title('Mean Squared Error by Training Sample Size')
plt.xlabel('Number of Training Samples')
plt.ylabel('Mean Squared Error')
plt.ylim((2600, 4000))  # Set the y-axis limits to make trends more visible
plt.grid(True)
plt.savefig('picture/ans_1.1.png')
plt.show()

# %%
# Plot Variance Score vs. Training Samples
plt.figure(figsize=(10, 5))
plt.plot(performance_metrics[:, 0], performance_metrics[:, 2], color='steelblue', marker='o', linestyle='-')
plt.title('Variance Score by Training Sample Size')
plt.xlabel('Number of Training Samples')
plt.ylabel('Variance Score')
plt.ylim((0, 0.5))  # Set the y-axis limits to make trends more visible
plt.grid(True)
plt.savefig('picture/ans_1.2.png')
plt.show()

# %% [markdown]
# ### plt.show()
# `plt.show()` 関数は、Matplotlibで作成した図を表示するために使用されます。スクリプトやプログラムの最後に `plt.show()` を配置すると、すべてのプロットが表示され、ユーザーがそれらを閲覧できる状態になります。対話型環境やJupyterノートブックのようにプロットが自動的に表示される環境では、この関数が不要な場合がありますが、それでも以下のような違いがあります：
#
# - **`plt.show()` がある場合**：
#   - プログラムは `plt.show()` で実行を停止し、ユーザーが生成されたウィンドウを閉じるまで待機します。
#   - すべての開いているフィギュアが表示され、フィギュアに対する対話が可能になります（ズーム、パン、保存など）。
#   - 一度 `plt.show()` を実行すると、表示されたフィギュアに対する後続の変更は反映されません。新しいフィギュアを作成するためには、再度プロット関数を呼び出す必要があります。
#
# - **`plt.show()` がない場合**：
#   - スクリプトやプログラムは自動的に次の行に進みます。
#   - Jupyterノートブックなどの環境では、セルを実行するたびにフィギュアが自動的に表示されますが、`plt.show()` がないとフィギュアが閉じられたときにPythonの対話セッションが継続することを保証するものではありません。
#   - スクリプトが完了した後、開いているすべてのフィギュアが閉じられます。
#
# したがって、対話型環境では `plt.show()` は省略できることが多いですが、スクリプトをファイルとして実行する場合や、ユーザーがフィギュアと対話できるようにしたい場合は、`plt.show()` を使用することが一般的です。
